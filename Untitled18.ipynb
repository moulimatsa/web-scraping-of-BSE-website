# %%
from selenium import webdriver
import time
import csv
import pandas as pd
import urllib

# %%
url = 'https://www.bseindia.com/stock-share-price/financials/results/500002/'

# %%
#normal_values


driver = webdriver.Chrome()
driver.implicitly_wait(10)
driver.get(url)
time.sleep(5)

pre_close = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(1) > div > table > tbody > tr:nth-child(1) > td.textsr")
pre_cl_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(1) > div > table > tbody > tr:nth-child(1) > td.textvalue.ng-binding")

for pre in pre_close:
    for pre1 in pre_cl_rel:
        x1 = pre.text.strip()
        y1 = pre1.text.strip()
        


open_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(1) > div > table > tbody > tr:nth-child(3) > td.textsr")
open_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(1) > div > table > tbody > tr:nth-child(3) > td.textvalue.ng-binding")

for open_v in open_val:
    for open_r in open_rel:
        x2 = open_v.text.strip()
        y2 = open_r.text.strip()


high_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(1) > div > table > tbody > tr:nth-child(5) > td.textsr")
high_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(1) > div > table > tbody > tr:nth-child(5) > td.textvalue.ng-binding")

for high_v in high_val:
    for high_r in high_rel:
        x3 = high_v.text.strip()
        y3 = high_r.text.strip()
        

        
low_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(1) > div > table > tbody > tr:nth-child(7) > td.textsr")
low_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(1) > div > table > tbody > tr:nth-child(7) > td.textvalue.ng-binding")

for low_v in low_val:
    for low_r in low_rel:
        x4 = low_v.text.strip()
        y4 = low_r.text.strip()
               
        
        
vwap_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(1) > div > table > tbody > tr:nth-child(9) > td.textsr")
vwap_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(1) > div > table > tbody > tr:nth-child(9) > td.textvalue.ng-binding")

for vwap_v in vwap_val:
    for vwap_r in vwap_rel:
        x5 = vwap_v.text.strip()
        y5 = vwap_r.text.strip()
               
        
        
fiftywkh_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(2) > div > table > tbody > tr:nth-child(1) > td.textsr > a")
fiftywkh_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(2) > div > table > tbody > tr:nth-child(1) > td.textvalue.ng-binding")

for fiftywkh_v in fiftywkh_val:
    for fiftywkh_r in fiftywkh_rel:
        x6 = fiftywkh_v.text.strip()
        y6 = fiftywkh_r.text.strip()
                
     

    
fiftywkl_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(2) > div > table > tbody > tr:nth-child(3) > td.textsr > a")
fiftywkl_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(2) > div > table > tbody > tr:nth-child(3) > td.textvalue.ng-binding")

for fiftywkl_v in fiftywkl_val:
    for fiftywkl_r in fiftywkl_rel:
        x7 = fiftywkl_v.text.strip()
        y7 = fiftywkl_r.text.strip()
           

upb_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(2) > div > table > tbody > tr:nth-child(5) > td.textsr")
upb_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(2) > div > table > tbody > tr:nth-child(5) > td.textvalue.ng-binding")

for upb_v in upb_val:
    for upb_r in upb_rel:
        x8 = upb_v.text.strip()
        y8 = upb_r.text.strip()
    


lpb_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(2) > div > table > tbody > tr:nth-child(7) > td.textsr")
lpb_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(2) > div > table > tbody > tr:nth-child(7) > td.textvalue.ng-binding")

for lpb_v in lpb_val:
    for lpb_r in lpb_rel:
        x9 = lpb_v.text.strip()
        y9 = lpb_r.text.strip()
        
        
        
avgqty_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(2) > div > table > tbody > tr:nth-child(9) > td.textsr")
avgqty_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(2) > div > table > tbody > tr:nth-child(9) > td.textvalue.ng-binding")

for avgqty_v in avgqty_val:
    for avgqty_r in avgqty_rel:
        x10 = avgqty_v.text.strip()
        y10 = avgqty_r.text.strip()
            
        
        
ttq_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(3) > div > table > tbody > tr:nth-child(1) > td.textsr")
ttq_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(3) > div > table > tbody > tr:nth-child(1) > td.textvalue.ng-binding")

for ttq_v in ttq_val:
    for ttq_r in ttq_rel:
        x11 = ttq_v.text.strip()
        y11 = ttq_r.text.strip()
        
        
        
turn_over_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(3) > div > table > tbody > tr:nth-child(3) > td.textsr")
turn_over_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(3) > div > table > tbody > tr:nth-child(3) > td.textvalue.ng-binding")

for turn_over_v in turn_over_val:
    for turn_over_r in turn_over_rel:
        x12 = turn_over_v.text.strip()
        y12 = turn_over_r.text.strip()
        
        
        
        
mcap_full_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(3) > div > table > tbody > tr:nth-child(5) > td.textsr")
mcap_full_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(3) > div > table > tbody > tr:nth-child(5) > td.textvalue.ng-binding")

for mcap_full_v in mcap_full_val:
    for mcap_full_r in mcap_full_rel:
        x13 = mcap_full_v.text.strip()
        y13 = mcap_full_r.text.strip()
        
        
mcap_ff_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(3) > div > table > tbody > tr:nth-child(7) > td.textsr")
mcap_ff_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(3) > div > table > tbody > tr:nth-child(7) > td.textvalue.ng-binding")

for mcap_ff_v in mcap_ff_val:
    for mcap_ff_r in mcap_ff_rel:
        x14 = mcap_ff_v.text.strip()
        y14 = mcap_ff_r.text.strip()
        

faceval_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(3) > div > table > tbody > tr:nth-child(9) > td.textsr ")
faceval_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(3) > div > table > tbody > tr:nth-child(9) > td.textvalue.ng-binding")

for faceval_v in faceval_val:
    for faceval_r in faceval_rel:
        x15 = faceval_v.text.strip()
        y15 = faceval_r.text.strip()
        
        
eps_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(4) > div > table > tbody > tr:nth-child(1) > td.textsr")
eps_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(4) > div > table > tbody > tr:nth-child(1) > td.textvalue.ng-binding")

for eps_v in eps_val:
    for eps_r in eps_rel:
        x16 = eps_v.text.strip()
        y16 = eps_r.text.strip()
        
        
        
ceps_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(4) > div > table > tbody > tr:nth-child(3) > td.textsr")
ceps_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(4) > div > table > tbody > tr:nth-child(3) > td.textvalue.ng-binding")

for ceps_v in ceps_val:
    for ceps_r in ceps_rel:
        x17 = ceps_v.text.strip()
        y17 = ceps_r.text.strip()
        
        
        
pe_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(4) > div > table > tbody > tr:nth-child(5) > td.textsr")
pe_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(4) > div > table > tbody > tr:nth-child(5) > td.textvalue.ng-binding")

for pe_v in pe_val:
    for pe_r in pe_rel:
        x18 = pe_v.text.strip()
        y18 = pe_r.text.strip()
        
        
        
pb_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(4) > div > table > tbody > tr:nth-child(7) > td.textsr")
pb_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(4) > div > table > tbody > tr:nth-child(7) > td.textvalue.ng-binding")

for pb_v in pb_val:
    for pb_r in pb_rel:
        x19 = pb_v.text.strip()
        y19 = pb_r.text.strip()
        
        
        
roe_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(4) > div > table > tbody > tr:nth-child(9) > td.textsr")
roe_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(4) > div > table > tbody > tr:nth-child(9) > td.textvalue.ng-binding")

for roe_v in roe_val:
    for roe_r in roe_rel:
        x20 = roe_v.text.strip()
        y20 = roe_r.text.strip()
        
        
        
category_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(5) > div > table > tbody > tr:nth-child(1) > td.textsr")
category_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(5) > div > table > tbody > tr:nth-child(1) > td.textvalue.ng-binding")

for category_v in category_val:
    for category_r in category_rel:
        x21 = category_v.text.strip()
        y21 = category_r.text.strip()
        
        
        
group_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(5) > div > table > tbody > tr:nth-child(3) > td.textsr")
group_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(5) > div > table > tbody > tr:nth-child(3) > td.textvalue.ng-binding")

for group_v in group_val:
    for group_r in group_rel:
        x22 = group_v.text.strip()
        y22 = group_r.text.strip()
        
            
        
index_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(5) > div > table > tbody > tr:nth-child(5) > td.textsr")
index_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(5) > div > table > tbody > tr:nth-child(5) > td.textvalue.ng-binding")

for index_v in index_val:
    for index_r in index_rel:
        x23 = index_v.text.strip()
        y23 = index_r.text.strip()
        
        
        
industry_val = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(5) > div > table > tbody > tr:nth-child(7) > td.textsr")
industry_rel = driver.find_elements_by_css_selector("#eqcommanheader > div:nth-child(5) > div > div:nth-child(5) > div > table > tbody > tr:nth-child(7) > td.textvalue.ng-binding")

for industry_v in industry_val:
    for industry_r in industry_rel:
        x24 = industry_v.text.strip()
        y24 = industry_r.text.strip()
        

header = ['id', x1, x2, x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,x16,x17,x18,x19,x20,x21,x22,x23,x24]
rows = [
    [1, y1,y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13,y14,y15,y16,y17,y18,y19,y20,y21,y22,y23,y24 ]
]
 
with open('try.csv', 'wt') as f:
    csv_writer = csv.writer(f, quotechar="'")
 
    csv_writer.writerow(header) 
 
    csv_writer.writerows(rows)

# %%
#financial_results

driver = webdriver.Chrome()
driver.implicitly_wait(10)
driver.get(url)

'''jun18q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[2]/td[2]/a').click()
sep18q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[2]/td[3]/a').click()
dec18q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[2]/td[4]/a').click()
mar19q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[2]/td[5]/a').click()
mar19y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[2]/td[7]/a').click()

jun17q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[3]/td[2]/a').click()
sep17q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[3]/td[3]/a').click()
dec17q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[3]/td[4]/a').click()
mar18q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[3]/td[5]/a').click()
mar18y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[3]/td[7]/a').click()

jun16q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[4]/td[2]/a').click()
sep16q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[4]/td[3]/a').click()
dec16q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[4]/td[4]/a').click()
mar17q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[4]/td[5]/a').click()
mar17y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[4]/td[7]/a').click()

jun15q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[5]/td[2]/a').click()
sep15q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[5]/td[3]/a').click()
dec15q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[5]/td[4]/a').click()
mar16q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[5]/td[5]/a').click()
mar16y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[5]/td[7]/a').click()

jun14q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[6]/td[2]/a').click()
sep14q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[6]/td[3]/a').click()
dec14q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[6]/td[4]/a').click()
mar15q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[6]/td[5]/a').click()
mar15y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[6]/td[7]/a').click()

jun13q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[7]/td[2]/a').click()
sep13q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[7]/td[3]/a').click()
dec13q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[7]/td[4]/a').click()
mar14q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[7]/td[5]/a').click()
mar14y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[7]/td[7]/a').click()

jun12q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[8]/td[2]/a').click()
sep12q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[8]/td[3]/a').click()
dec12q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[8]/td[4]/a').click()
mar13q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[8]/td[5]/a').click()
mar13y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[8]/td[7]/a').click()

jun11q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[9]/td[2]/a').click()
sep11q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[9]/td[3]/a').click()
dec11q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[9]/td[4]/a').click()
mar12q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[9]/td[5]/a').click()
mar12y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[9]/td[7]/a').click()

jun10q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[10]/td[2]/a').click()
sep10q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[10]/td[3]/a').click()
dec10q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[10]/td[4]/a').click()
mar11q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[10]/td[5]/a').click()
mar11y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[10]/td[7]/a').click()

jun9q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[11]/td[2]/a').click()
sep9q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[11]/td[3]/a').click()
dec9q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[11]/td[4]/a').click()
mar10q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[11]/td[5]/a').click()
mar10y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[11]/td[7]/a').click()

jun8q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[12]/td[2]/a').click()
sep8q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[12]/td[3]/a').click()
dec8q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[12]/td[4]/a').click()
mar9q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[12]/td[5]/a').click()
mar9y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[12]/td[7]/a').click()

jun7q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[13]/td[2]/a').click()
sep7q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[13]/td[3]/a').click()
dec7q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[13]/td[4]/a').click()
mar8q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[13]/td[5]/a').click()
mar8y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[13]/td[7]/a').click()

jun6q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[14]/td[2]/a').click()
sep6q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[14]/td[3]/a').click()
dec6q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[14]/td[4]/a').click()
mar7q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[14]/td[5]/a').click()
mar7y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[14]/td[7]/a').click()

jun5q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[15]/td[2]/a').click()
sep5q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[15]/td[3]/a').click()
dec5q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[15]/td[4]/a').click()
mar6q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[15]/td[5]/a').click()
mar6y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[15]/td[7]/a').click()

jun4q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[16]/td[2]/a').click()
sep4q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[16]/td[3]/a').click()
dec4q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[16]/td[4]/a').click()
mar5q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[16]/td[5]/a').click()
mar5y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[16]/td[7]/a').click()
'''

def standalone():
    time.sleep(3)
    driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_lnkStandalone"]').click()
    time.sleep(1)
    x = driver.find_elements_by_xpath('//*[@id="ContentPlaceHolder1_lnkDownload"]')
    time.sleep(2)
    for xs in x:
        xs.click()
    

def detailed():
    time.sleep(1)
    driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_lnkDetailed"]').click()
    time.sleep(1)
    y = driver.find_elements_by_xpath('//*[@id="ContentPlaceHolder1_lnkDownload"]')
    time.sleep(2)
    for ys in y:
        ys.click()
        

def consolidated():
    time.sleep(1)
    driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_lnkConsolidated"]').click()
    time.sleep(3)
    table = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tbl_typeID"]')
    body = table.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tbl_typeID"]/tbody')
    
    file_data = []
    
         
    body_rows = body.find_elements_by_tag_name('tr')
    
    for row in body_rows:
        data = row.find_elements_by_tag_name('td')
        file_row = []
        for datum in data:
            datum_text = datum.text
            file_row.append(datum_text)
        file_data.append(",".join(file_row))
    
    
    f = open("src3.csv",'a+')
    f.write("\n".join(file_data))
    
    

'''k = ['jun18q','sep18q','dec18q','mar19q','mar19y','jun17q','sep17q','dec17q','mar18q','mar18y','jun16q','sep16q','dec16q','mar17q','mar17y','jun15q','sep15q','dec15q','mar16q','mar16y',
     'jun14q','sep14q','dec14q','mar15q','mar15y','jun13q','sep13q','dec13q','mar14q','mar14y','jun12q','sep12q','dec12q','mar13q','mar13y',
     'jun11q','sep11q','dec11q','mar12q','mar12y','jun10q','sep10q','dec10q','mar11q','mar11y','jun9q','sep9q','dec9q','mar10q','mar10y','jun8q','sep8q','dec8q','mar9q','mar9y',
     'jun7q','sep7q','dec7q','mar8q','mar8y','jun6q','sep6q','dec6q','mar7q','mar7y','jun5q','sep5q','dec5q','mar6q','mar6y','jun4q','sep4q','dec4q','mar5q','mar5y']
         ''' 

def main():
    time.sleep(1)

    jun18q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[2]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep18q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[2]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec18q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[2]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar19q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[2]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar19y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[2]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun17q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[3]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep17q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[3]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec17q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[3]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar18q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[3]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar18y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[3]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun16q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[4]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep16q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[4]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec16q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[4]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar17q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[4]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar17y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[4]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun15q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[5]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep15q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[5]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec15q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[5]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar16q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[5]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar16y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[5]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun14q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[6]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep14q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[6]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec14q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[6]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar15q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[6]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar15y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[6]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun13q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[7]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep13q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[7]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec13q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[7]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar14q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[7]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar14y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[7]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun12q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[8]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep12q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[8]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec12q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[8]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar13q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[8]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar13y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[8]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun11q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[9]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep11q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[9]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec11q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[9]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar12q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[9]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar12y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[9]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun10q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[10]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep10q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[10]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec10q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[10]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar11q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[10]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar11y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[10]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun9q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[11]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep9q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[11]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec9q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[11]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar10q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[11]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar10y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[11]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun8q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[12]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep8q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[12]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec8q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[12]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar9q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[12]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar9y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[12]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun7q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[13]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep7q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[13]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec7q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[13]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar8q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[13]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar8y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[13]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun6q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[14]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep6q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[14]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec6q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[14]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar7q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[14]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar7y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[14]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun5q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[15]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep5q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[15]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec5q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[15]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar6q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[15]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar6y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[15]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    jun4q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[16]/td[2]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    sep4q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[16]/td[3]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    dec4q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[16]/td[4]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar5q = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[16]/td[5]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)
    mar5y = driver.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tdData"]/table/tbody/tr/td/table/tbody/tr[16]/td[7]/a').click()
    time.sleep(1)
    standalone()
    detailed()
    consolidated()
    time.sleep(2)
    driver.execute_script("window.history.go(-4)")
    time.sleep(2)

    
if __name__ == "__main__":
    main()

# %%
#corp_announcements


options = webdriver.ChromeOptions()

download_dir = r'C:\Users\matsa\Downloads\new11.pdf'
os.mkdir(download_dir)
profile = {"plugins.plugins_list": [{"enabled": False, "name": "Chrome PDF Viewer"}],
               "download.default_directory": download_dir , "download.extensions_to_open": "applications/pdf"}
options.add_experimental_option('prefs', profile)
driver = webdriver.Chrome(options=options)

driver.implicitly_wait(10)
driver.get(url)
time.sleep(1)
x = driver.find_elements_by_xpath('//*[@id="lblann"]/table/tbody/tr[4]/td/table/tbody/tr/td/a/i')


for xs in x:
    time.sleep(3)
    xs.click()

# %%
url = 'https://www.bseindia.com/stock-share-price/housing-development-finance-corpltd/hdfc/500010/'

# %%
#buy_sell_price


driver = webdriver.Chrome()
driver.get(url)
time.sleep(3)
item = driver.find_element_by_xpath('//*[@id="deribody"]/div[2]/div[2]/div[2]/div/div[1]/div/table/tbody/tr/td/table')
driver.execute_script("arguments[0].click();", item)
time.sleep(2)
for table in driver.find_elements_by_xpath('//*[@id="deribody"]/div[2]/div[2]/div[2]/div/div[1]/div/table/tbody/tr/td/table/tbody/tr'):
    data = [item.text.strip() for item in table.find_elements_by_xpath(".//*[self::td or self::th]")]
    print(data)
    with open("your_csv_file.csv", "a+") as f:
        f.write("\n".join(data))
# Out:
# ['Market Depth (29 Jul 2019)', 'Market Depth', '(29 Jul 2019)', '']
# ['']
# ['BUY', '', 'SELL']
# ['']
# ['Qty', 'Price', '', 'Price', 'Qty']
# ['']
# ['14', '2,112.50', '', '2,114.20', '11']
# ['']
# ['55', '2,112.45', '', '2,114.40', '30']
# ['']
# ['66', '2,112.40', '', '2,114.45', '13']
# ['']
# ['30', '2,112.35', '', '2,114.55', '43']
# ['']
# ['15', '2,112.30', '', '2,114.75', '30']
# ['']
# ['46,307', 'Total', '', 'Total', '48,850']
